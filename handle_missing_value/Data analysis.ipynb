# %%
import pandas as pd

# %%
df = pd.read_csv('newdata.csv')

# %%
df.corr()
# Out:
# <ipython-input-5-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              WIND       IND      RAIN     IND.1     T.MAX     IND.2     T.MIN  \
# WIND     1.000000 -0.038578  0.120876  0.070806 -0.232035  0.048513 -0.098046
# IND     -0.038578  1.000000 -0.148535 -0.028740 -0.070145 -0.015800 -0.044535
# RAIN     0.120876 -0.148535  1.000000  0.023181 -0.049722  0.011978  0.012587
# IND.1    0.070806 -0.028740  0.023181  1.000000  0.011999  0.909902 -0.122895
# T.MAX   -0.232035 -0.070145 -0.049722  0.011999  1.000000 -0.078627  0.762820
# IND.2    0.048513 -0.015800  0.011978  0.909902 -0.078627  1.000000 -0.254793
# T.MIN   -0.098046 -0.044535  0.012587 -0.122895  0.762820 -0.254793  1.000000
# T.MIN.G  0.012245 -0.062218  0.026541 -0.002237  0.658976 -0.126778  0.879182
#
#           T.MIN.G
# WIND     0.012245
# IND     -0.062218
# RAIN     0.026541
# IND.1   -0.002237
# T.MAX    0.658976
# IND.2   -0.126778
# T.MIN    0.879182
# T.MIN.G  1.000000

# %%
import seaborn

# %%
seaborn.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-9-38f7417860ea>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   seaborn.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
df['WIND'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df.hist()
# Out:
# array([[<Axes: title={'center': 'WIND'}>,
#         <Axes: title={'center': 'IND'}>,
#         <Axes: title={'center': 'RAIN'}>],
#        [<Axes: title={'center': 'IND.1'}>,
#         <Axes: title={'center': 'T.MAX'}>,
#         <Axes: title={'center': 'IND.2'}>],
#        [<Axes: title={'center': 'T.MIN'}>,
#         <Axes: title={'center': 'T.MIN.G'}>, <Axes: >]], dtype=object)

# %%
fig=plt.figure(figsize=(20,20))

# %%
plt.show()

# %%
ax=fig.gca()
df.hist(ax=ax)
# Out:
# <ipython-input-19-5caad4d4b487>:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax)
# array([[<Axes: title={'center': 'WIND'}>,
#         <Axes: title={'center': 'IND'}>,
#         <Axes: title={'center': 'RAIN'}>],
#        [<Axes: title={'center': 'IND.1'}>,
#         <Axes: title={'center': 'T.MAX'}>,
#         <Axes: title={'center': 'IND.2'}>],
#        [<Axes: title={'center': 'T.MIN'}>,
#         <Axes: title={'center': 'T.MIN.G'}>, <Axes: >]], dtype=object)

# %%
fig
